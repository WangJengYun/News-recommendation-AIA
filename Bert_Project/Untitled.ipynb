# %%
import json
path = '/home/jovyan/at081-group39/python_code/Bert_Project/output_title.jsonl'
data = []
with open(path,'r') as file :
#     data = json.loads(file.dumps())
    for line in file:
        data.append(json.loads(line))

# %%
# for i in range():
    
print(data[1]['doc_vector'])
# Out:
# [{'-1': [0.58027, -0.73428, -0.78301, 0.77994, 0.18043, -0.44269, 0.20189, -0.19289, -0.09066, 0.08304, -0.43281, -0.77488, -0.25343, 0.31778, 1.22819, -0.03418, -0.12772, -0.38914, 0.6036, 0.19095, -0.4656, -0.05408, 0.2397, -0.27361, 0.0749, -0.42162, -0.34378, -0.56529, 0.12726, 0.41416, 0.15659, -0.33077, 0.27569, -0.63344, 0.25145, -0.29562, -0.0266, 0.37211, -0.28647, -0.05532, 0.52559, -0.32081, 0.26889, -0.08692, -0.21808, 0.30578, 0.04322, -0.17262, -0.08602, 0.35989, -0.1606, 8.97625, -0.18608, 0.05173, -0.87927, 0.40703, 0.40696, 0.4069, -0.20528, -0.48299, -0.23405, -0.80037, 0.12153, -0.42224, -0.0292, -0.70879, 0.31662, 0.32416, 0.60787, -0.08279, -0.11058, -0.52928, 0.0403, -0.03861, 0.31321, 0.20315, -0.08287, -0.01305, -0.25281, 0.08712, -0.75231, -0.2196, 0.20792, -0.21351, -0.02075, 0.28858, 0.32496, -0.46002, -0.08095, -0.39416, 0.2421, 0.12119, 0.06592, 0.1879, 0.18704, 0.03823, 0.42471, -0.46951, -0.48105, -0.23249, -0.65837, 0.27589, 0.13622, -0.72518, -0.28681
# ...

# %%
122%20
# Out:
# 2
